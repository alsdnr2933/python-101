# %%
print("hello world")
# Out:
# hello world

# %%
user_name = input("enter you name : ")
print("welcome " + user_name)
# Out:
# welcomekim

# %%
print("welcom to name generator")
first_name = input("what was your nick name?")
sec_name = input("what was your favorite food?")
print("result " + first_name + sec_name)
# Out:
# welcom to name generator
# result ukramen

# %%
print(f"enter anything {input('enter something:')}")
# Out:
# enter anthing sssss

# %%
user_age = input("how old are you?")
if int(user_age) >= 18:
    print(f"you can enter. because you are {user_age}")
elif int(user_age) < 18:
    print(f"you can't enter. because you are {user_age}")
# Out:
# you can't enter. because you are 15
